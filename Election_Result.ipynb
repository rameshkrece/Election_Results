# %%
import pandas as pd
import mysql.connector
mydb = mysql.connector.connect(user='admin', password='afx9EHIec0pFUwqNammj', host='electionresult1.clepjdgya9gn.us-east-1.rds.amazonaws.com', database='electionresult1')
mycursor = mydb.cursor()
mycursor.execute("select * from election_result")
myresult = mycursor.fetchall()
print(myresult)
# Out:
# [('Andaman & Nicobar Islands', 'Bahujan Samaj Party', 503, 0, 503, 1823, 414, 4, 22946182), ('Andhra Pradesh', 'Bharatiya Janata Party', 428, 282, 146, 1271, 2818, 31, 171657549), ('Arunachal Pradesh', 'Communist Party of India', 67, 1, 66, 318, 77, 1, 4327298), ('Assam', 'Communist Party of India  (Marxist)', 93, 9, 84, 4979, 316, 3, 17986773), ('Bihar', 'Indian National Congress', 464, 44, 420, 3051, 1887, 19, 106938242), ('Chandigarh', 'Nationalist Congress Party', 36, 6, 30, 1178, 150, 2, 8635554), ('Chhattisgarh', 'Aam Aadmi Party', 432, 4, 428, 2827, 201, 2, 11325635), ('Dadra & Nagar Haveli', 'AJSU Party', 10, 0, 10, 3234, 9, 0, 488719), ('Daman & Diu', 'All India Anna Dravida Munnetra Kazhagam', 40, 37, 3, 672, 290, 3, 18115825), ('Goa', 'All India Forward Bloc', 39, 0, 39, 5055, 22, 0, 1211418), ('Gujarat', 'All India N.R. Congress', 1, 1, 0, 1570, 4, 0, 255826), ('Haryana', 'All India Trinamool Congress', 131, 34, 97, 1527, 350, 4, 21259681), ('Himachal Pradesh', 'All India
# ...

# %%
import pandas as pd
import mysql.connector
mydb = mysql.connector.connect(user='admin', password='afx9EHIec0pFUwqNammj', host='electionresult1.clepjdgya9gn.us-east-1.rds.amazonaws.com', database='electionresult1')
c = mydb.cursor()
c.execute("select * from election_result")
df = pd.DataFrame(c.fetchall(),columns = ["State","Party","Total_no_of_seats","Won","Loss","lea","Previous_Election_won","Percentage_of_change","Total_Votes"])
print(df)
# Out:
#                           State                                  Party  \
# 0     Andaman & Nicobar Islands                    Bahujan Samaj Party
# 1                Andhra Pradesh                 Bharatiya Janata Party
# 2             Arunachal Pradesh               Communist Party of India
# 3                         Assam    Communist Party of India  (Marxist)
# 4                         Bihar               Indian National Congress
# ...                         ...                                    ...
# 5563                  Rajasthan                           Voters Party
# 5564                     Sikkim                 Welfare Party Of India
# 5565                 Tamil Nadu                            Yuva Sarkar
# 5566                    Tripura  Yuvajana Sramika Rythu Congress Party
# 5567              Uttar Pradesh                            Independent
#
#       Total_no_of_seats  Won  Loss    lea  Previous_Election_won  \
# ...

# %%
import seaborn as sns
import numpy as np
sns.relplot(data = df, x ="Previous_Election_won", y ="State")
# Out:
# C:\Users\Ramesh\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import seaborn as sns
import numpy as np
sns.barplot(data = df, x ="Won", y ="Previous_Election_won")
# Out:
# <AxesSubplot:xlabel='Won', ylabel='Previous_Election_won'>
